# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from torch.optim.lr_scheduler import ReduceLROnPlateau

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F 
from torch.utils.data import Dataset, DataLoader,TensorDataset

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.empty_cache()
print(device)
print(torch.cuda.get_device_name(0))
print(torch.cuda.memory_summary())
# Out:
# cuda
# NVIDIA GeForce RTX 4070 Laptop GPU
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  63915 KiB | 148046 KiB |   7898 GiB |   7898 GiB |
# |       from large pool |  62792 KiB | 144049 KiB |   7516 GiB |   7516 GiB |
# |       from small pool |   1123 KiB |   5533 KiB |    381 GiB |    381 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  63915 KiB | 148046 KiB |   7898 GiB |   7898 GiB |
# |       from large pool |  62792 KiB | 144049 KiB |   7516 GiB |   7516 GiB |
# |       from small pool |   1123 KiB |   5533 KiB |    381 GiB |    381 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  63804 KiB | 141956 KiB |   7485 GiB |   7485 GiB |
# |       from large pool |  62792 KiB | 138069 KiB |   7105 GiB |   7105 GiB |
# |       from small pool |   1012 KiB |   5421 KiB |    380 GiB |    380 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   | 108544 KiB | 188416 KiB | 188416 KiB |  79872 KiB |
# |       from large pool | 106496 KiB | 180224 KiB | 180224 KiB |  73728 KiB |
# |       from small pool |   2048 KiB |   8192 KiB |   8192 KiB |   6144 KiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  44628 KiB |  67362 KiB |   5101 GiB |   5101 GiB |
# |       from large pool |  43704 KiB |  65851 KiB |   4703 GiB |   4703 GiB |
# |       from small pool |    924 KiB |   3718 KiB |    398 GiB |    398 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     327    |     359    |    7211 K  |    7211 K  |
# |       from large pool |      10    |      22    |    1196 K  |    1196 K  |
# |       from small pool |     317    |     348    |    6015 K  |    6014 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     327    |     359    |    7211 K  |    7211 K  |
# |       from large pool |      10    |      22    |    1196 K  |    1196 K  |
# |       from small pool |     317    |     348    |    6015 K  |    6014 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |       7    |      14    |      14    |       7    |
# |       from large pool |       6    |      10    |      10    |       4    |
# |       from small pool |       1    |       4    |       4    |       3    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      14    |      68    |    3203 K  |    3203 K  |
# |       from large pool |       6    |      11    |     546 K  |     546 K  |
# |       from small pool |       8    |      62    |    2656 K  |    2656 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
def get_SNP(data):   
    df = pd.read_csv(f"data/{data}")
    X = df.drop(["Phenotype", "Genotype"],axis=1) # All SNP columns
    y = df['Phenotype']  # Convert phenotype to float

    variances = X.var(axis=0)
    optimal_threshold = variances.quantile(0.25)
    var_thresh = VarianceThreshold(threshold=optimal_threshold) 
    X_var_filtered = pd.DataFrame(var_thresh.fit_transform(X), columns=X.columns[var_thresh.get_support()])
    n_features = X_var_filtered.shape[1]

    X_var_filtered = np.array(X_var_filtered)
    y = np.array(y)

    # Train-Test split (80% train, 20% test)
    X_train, X_test, y_train, y_test = train_test_split(
        X_var_filtered, y, test_size=0.1)

    # Further split train into train/val (80/20 split of the train set)
    X_train, X_val, y_train, y_val = train_test_split(
        X_train, y_train, test_size=0.1)
    
    input_dim = X_train.shape[1]

    class SNPPhenotypeDataset(Dataset):
        def __init__(self, X, y):
            self.X = torch.tensor(X, dtype=torch.float32)  
            self.y = torch.tensor(y, dtype=torch.float32).view(-1, 1)  

        def __len__(self):
            return len(self.X)

        def __getitem__(self, idx):
            return self.X[idx].unsqueeze(0), self.y[idx]
        
    train_dataset = SNPPhenotypeDataset(X_train, y_train)
    val_dataset   = SNPPhenotypeDataset(X_val, y_val)
    test_dataset  = SNPPhenotypeDataset(X_test, y_test)

    batch_size = 8

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader   = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader, test_loader,input_dim

# %%
def createCNNmodel(blocks,hidden_units, drop,lr,decay,batch=True,activation_type="relu",optimizer_type="adam"):

    class CNNRegressor(nn.Module):
        def __init__(self, blocks,hidden_units, drop, activation_type, input_length):
            super(CNNRegressor, self).__init__()

            self.nCons = len(blocks)
            self.nLayers = len(hidden_units)

            self.activations = {
                'relu': F.relu,              
                'leaky_relu': F.leaky_relu,  
                'elu': F.elu,
                "tanh": F.tanh       
                }
            
            self.activation = self.activations.get(activation_type.lower(), F.relu)
            self.dropout = nn.Dropout(drop)
            
            #CNN part
            self.cnn_layers = nn.ModuleDict()
            self.batch_con = nn.ModuleDict()
            self.pools = nn.ModuleDict()

            self.cnn_layers["input"] = nn.Conv1d(in_channels=1, out_channels=blocks[0], kernel_size=3, padding=1)
            self.batch_con["input"] = nn.BatchNorm1d(blocks[0])
            self.pools["input"] = nn.MaxPool1d(kernel_size=2)


            for j in range(self.nCons - 1):
                self.cnn_layers[f"hidden{j}"] = nn.Conv1d(in_channels=blocks[j], out_channels=blocks[j+1], kernel_size=3, padding=1)
                self.batch_con[f"hidden{j}"] = nn.BatchNorm1d(blocks[j+1])
                self.pools[f"hidden{j}"] = nn.MaxPool1d(kernel_size=2)
                
            
            self.cnn_layers["output"] = nn.Conv1d(in_channels=blocks[-1], out_channels=blocks[-1],kernel_size=3, padding=1 )


            output_length = input_length
            # Account for each pooling layer
            for _ in range(self.nCons):
                output_length = output_length // 2
            
            flattened_size = blocks[-1] * output_length
            
            
            #Dense part
            
            self.ffn_layers = nn.ModuleDict()
            self.batch_lin = nn.ModuleDict()

            self.ffn_layers["input"] = nn.Linear(flattened_size,hidden_units[0])
            self.batch_lin["input"] = nn.BatchNorm1d(hidden_units[0])

            for i in range(self.nLayers - 1):
                self.ffn_layers[f"hidden{i}"] = nn.Linear(hidden_units[i], hidden_units[i+1])
                self.batch_lin[f"hidden{i}"] = nn.BatchNorm1d(hidden_units[i+1])

            self.ffn_layers["output"] = nn.Linear(hidden_units[-1], 1)



        def forward(self,x):

            #CNN forward pass
            x = self.cnn_layers['input'](x)
            if batch:
                x = self.batch_con["input"](x)
            x = self.activation(x)
            x = self.pools["input"](x)

            for j in range(self.nCons - 1):
                x = self.cnn_layers[f'hidden{j}'](x)
                if batch:
                    x = self.batch_con[f'hidden{j}'](x)
                x = self.activation(x)
                x = self.pools[f'hidden{j}'](x)
                
            
            x = self.cnn_layers["output"](x)

            # Dense forward pass
            x = torch.flatten(x,start_dim=1)

            x = self.ffn_layers["input"](x)
            if batch:
                x = self.batch_lin["input"](x)
            x = self.activation(x)

            for i in range(self.nLayers - 1):
                x = self.ffn_layers[f'hidden{i}'](x)
                if batch:
                    x = self.batch_lin[f'hidden{i}'](x)
                x = self.activation(x)
                x = self.dropout(x)

            # return output layer
            x = self.ffn_layers['output'](x)
            return x

    # Instantiate model
    input_length = input_dim  # D, number of features after feature selection

    model = CNNRegressor(blocks,hidden_units, drop, activation_type, input_length)

    criterion = nn.MSELoss()
    optimizers = {
    'adam': lambda: torch.optim.Adam(model.parameters(), lr=lr, weight_decay=decay),
    'sgd': lambda: torch.optim.SGD(model.parameters(), lr=lr, weight_decay=decay, momentum=0.9),
    "adamw": lambda: torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=decay),
    "rmsprop": lambda: torch.optim.RMSprop(model.parameters(), lr=lr, weight_decay=decay, momentum=0.9),
    }
    optimizer = optimizers.get(optimizer_type.lower(), optimizers['adam'])()

    return model, criterion, optimizer

# %%
def trainAndEval(model,criterion,optimizer,train_loader,val_loader,max_epochs=1000,patience=500):
    best_val_loss = float("inf")
    train_losses = []
    val_losses = []
    model.to(device)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

    # Training loop
    for epoch in range(max_epochs):
        model.train()
        running_train_loss = 0.0
        
        for batch_X, batch_y in train_loader:
            batch_X, batch_y = batch_X.to(device), batch_y.to(device).view(-1, 1)  # Reshape y to match output

            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

            running_train_loss += loss.item() * batch_X.size(0)

        epoch_train_loss = running_train_loss / len(train_loader.dataset)
        train_losses.append(epoch_train_loss)

        # Validation
        model.eval()
        running_val_loss = 0.0
        with torch.no_grad():
            for batch_X, batch_y in val_loader:
                batch_X, batch_y = batch_X.to(device), batch_y.to(device).view(-1, 1)  # Reshape y to match output
                outputs = model(batch_X)
                loss = criterion(outputs, batch_y)
                running_val_loss += loss.item() * batch_X.size(0)

        epoch_val_loss = running_val_loss / len(val_loader.dataset)
        val_losses.append(epoch_val_loss)
        
        # Update learning rate based on validation loss
        scheduler.step(epoch_val_loss)

        #print(f"Epoch [{epoch+1}/{max_epochs}] | Train Loss: {epoch_train_loss:.4f} | Val Loss: {epoch_val_loss:.4f}")

        # Early Stopping Check
        if epoch_val_loss < best_val_loss:
            best_val_loss = epoch_val_loss
            best_model_state = model.state_dict()
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= patience:
            #print(f"Early stopping triggered after {epoch+1} epochs")
            #print(f"Final Train loss: {train_losses[-1]:.4f} | Final Val Loss: {val_losses[-1]:.4f}")
            break

    # Load best model for evaluation
    if 'best_model_state' in locals():
        model.load_state_dict(best_model_state)
    
    return model

# %%
def grid_search_CNN(target_r2=0.7, data_folder="data"):
    # Create a DataFrame to store best results for each dataset
    best_results_df = pd.DataFrame(columns=[
        'Dataset', 'MSE', 'MAE', 'R2', 'Units', 'Convolutions', 'Dropout', 'Learning_Rate', 
        'Weight_Decay', 'Epochs', 'Activation', 'Optimizer', 'Patience'
    ])
    
    # Iterate through each dataset in the folder
    for data_file in os.listdir(data_folder):
        if not data_file.endswith('.csv'):
            continue
            
        print(f"\n\n{'='*50}")
        print(f"Processing dataset: {data_file}")
        print(f"{'='*50}")
        
        # Create a DataFrame to store all trial results for this dataset
        all_trials_df = pd.DataFrame(columns=[
            'Trial', 'MSE', 'MAE', 'R2', 'Convolutions', 'Units', 'Dropout', 'Learning_Rate', 
            'Weight_Decay', 'Epochs', 'Activation', 'Optimizer', 'Patience'
        ])
        
        try:
            train_loader, val_loader, test_loader, input_dim = get_SNP(data_file)
            
            # Define parameter grid
            param_grid = {
                "NUM_EPOCH": [250, 350, 450],
                "NUM_UNITS": [[48, 24, 16, 8],
                              [32, 16, 16, 8], 
                             [16, 16, 16, 16]], 
                "DROP": [0.1, 0.2, 0.3],                       
                "LR": [0.001, 0.0005, 0.0001],                       
                "DECAY": [1e-4, 1e-5],                 
                "PATIENCE": 20,
                "ACTIVATION": ["relu", "leaky_relu", "tanh", "elu"],
                "OPTIMIZER": ["adam", "sgd", "adamw", "rmsprop"],
                "CONVOLUTIONS": [[32,16,16], [32,16,8], [16,16,16]]    
            }
            
            # Calculate total number of combinations
            total_combinations = (
                len(param_grid["NUM_UNITS"]) * 
                len(param_grid["DROP"]) *
                len(param_grid["LR"]) * 
                len(param_grid["DECAY"]) *
                len(param_grid["NUM_EPOCH"]) *
                len(param_grid["ACTIVATION"]) *
                len(param_grid["OPTIMIZER"]) *
                len(param_grid["CONVOLUTIONS"])

            )
            
            print(f"Total parameter combinations to try: {total_combinations}")
            
            best_r2 = -float('inf')
            best_params = None
            best_model = None
            best_metrics = None
            current_trial = 0
            
            # Iterate through all parameter combinations
            for epochs in param_grid["NUM_EPOCH"]:
                for blocks in param_grid["CONVOLUTIONS"]:
                    for units in param_grid["NUM_UNITS"]:
                        for act in param_grid["ACTIVATION"]:
                            for opt in param_grid["OPTIMIZER"]:
                                for drop in param_grid["DROP"]:
                                    for lr in param_grid["LR"]:
                                        for decay in param_grid["DECAY"]:
                                            current_trial += 1
                                            
                                            current_params = {
                                                "num_epochs": epochs,
                                                'num_units': units,
                                                'drop': drop,
                                                'lr': lr,
                                                'decay': decay,
                                                "acts": act,
                                                "opts": opt,
                                                "patience": param_grid["PATIENCE"],
                                                "blocks": blocks
                                            }
                                            
                                            print(f"\nTrial {current_trial}/{total_combinations}")
                                            print("Current parameters:", current_params)
                                            
                                            # Create and train model
                                            model, criterion, optimizer = createCNNmodel(
                                                hidden_units=units,
                                                blocks=blocks,
                                                drop=drop,
                                                lr=lr, 
                                                decay=decay,
                                                optimizer_type=opt,
                                                activation_type=act,
                                                input_length=input_dim
                                            )
                                            
                                            # Train model and get metrics
                                            trained_model = trainAndEval(
                                                model, criterion, optimizer, 
                                                max_epochs=epochs, 
                                                patience=param_grid["PATIENCE"],
                                                train_loader=train_loader,
                                                val_loader=val_loader
                                            )
                                            
                                            # Get predictions on test set
                                            model.eval()
                                            with torch.no_grad():
                                                all_preds = []
                                                all_targets = []
                                                for batch_X, batch_y in test_loader:
                                                    batch_X = batch_X.to(device)
                                                    outputs = model(batch_X)
                                                    all_preds.append(outputs.cpu().numpy())
                                                    all_targets.append(batch_y.numpy())
                                                    
                                            y_pred = np.concatenate(all_preds).reshape(-1)
                                            y_true = np.concatenate(all_targets).reshape(-1)
                                            
                                            # Calculate metrics
                                            mse = mean_squared_error(y_true, y_pred)
                                            mae = mean_absolute_error(y_true, y_pred)
                                            r2 = r2_score(y_true, y_pred)
                                            
                                            print(f"R2 Score: {r2:.4f}")
                                            print(f"MSE Score: {mse:.4f}")
                                            print(f"MAE Score: {mae:.4f}")
                                            
                                            # Add results to the dataset's trial DataFrame
                                            trial_results = {
                                                'Trial': current_trial,
                                                'MSE': mse,
                                                'MAE': mae,
                                                'R2': r2,
                                                'Units': str(units),
                                                'Dropout': drop,
                                                'Learning_Rate': lr,
                                                'Weight_Decay': decay,
                                                'Epochs': epochs,
                                                'Activation': act,
                                                'Optimizer': opt,
                                                'Patience': param_grid["PATIENCE"],
                                                'Convolutions': blocks
                                            }
                                            all_trials_df = pd.concat([all_trials_df, pd.DataFrame([trial_results])], ignore_index=True)
                                            
                                            # Save current trial results to CSV (append mode)
                                            dataset_name = data_file.split('.')[0]
                                            trials_csv_path = f"CNN_results/grid_search_{dataset_name}.csv"
                                            
                                            # Create directory if it doesn't exist
                                            os.makedirs("CNN_results", exist_ok=True)
                                            
                                            # Save with header only if file doesn't exist
                                            all_trials_df.iloc[-1:].to_csv(
                                                trials_csv_path, 
                                                mode='a', 
                                                header=not os.path.exists(trials_csv_path),
                                                index=False
                                            )
                                            
                                            # Update best results if better R2 found
                                            if r2 > best_r2:
                                                best_r2 = r2
                                                best_params = current_params
                                                best_model = trained_model
                                                best_metrics = {
                                                    'r2': r2,
                                                    'mse': mse,
                                                    'mae': mae
                                                }
                                                print("New best R2 score!")
                                                
                                                # Save the best model so far
                                                model_save_path = f"CNN_models/best_model_{dataset_name}.pth"
                                                os.makedirs('CNN_models', exist_ok=True)
                                                torch.save(best_model.state_dict(), model_save_path)
                                            
                                            # Check if target achieved
                                            if r2 >= target_r2:
                                                print(f"\nTarget R2 score of {target_r2} achieved!")
                                                break
                                            
            best_result = {
                'Dataset': data_file,
                'MSE': best_metrics['mse'],
                'MAE': best_metrics['mae'],
                'R2': best_metrics['r2'],
                'Units': str(best_params['num_units']),
                'Dropout': best_params['drop'],
                'Learning_Rate': best_params['lr'],
                'Weight_Decay': best_params['decay'],
                'Epochs': best_params['num_epochs'],
                'Activation': best_params['acts'],
                'Optimizer': best_params['opts'],
                'Patience': best_params['patience'],
                'Convolutions': best_params['blocks']
            }
            best_results_df = pd.concat([best_results_df, pd.DataFrame([best_result])], ignore_index=True)
            
  
            print("\nGrid search completed for this dataset!")
            print("\nBest parameters found:")
            for param, value in best_params.items():
                print(f"{param}: {value}")
            print(f"\nBest metrics:")
            print(f"R2: {best_metrics['r2']:.4f}")
            print(f"MSE: {best_metrics['mse']:.4f}") 
            print(f"MAE: {best_metrics['mae']:.4f}")
            
        except Exception as e:
            print(f"Error processing dataset {data_file}: {str(e)}")
            continue
    

    os.makedirs('CNN_results', exist_ok=True)
    best_results_df.to_csv("CNN_results/best_models_summary.csv", index=False)
    
    print("\nAll datasets processed. Best results saved to 'results/best_models_summary.csv'")
    

    best_overall_idx = best_results_df['R2'].idxmax()
    best_overall_dataset = best_results_df.loc[best_overall_idx, 'Dataset']
    print(f"\nBest overall model found for dataset: {best_overall_dataset}")
    print(f"R2 Score: {best_results_df.loc[best_overall_idx, 'R2']:.4f}")
    
    return best_params, best_model, best_metrics

# %%
best_params, best_model, best_metrics = grid_search_CNN(target_r2=0.9,data_folder="data")
# Out:
# ==================================================
# Processing dataset: filtered_00001.csv
# ==================================================
# Total parameter combinations to try: 7776
#
# Trial 1/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2847
# MSE Score: 0.6145
# MAE Score: 0.6669
# New best R2 score!
#
# Trial 2/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_2788\1428187504.py:148: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_trials_df = pd.concat([all_trials_df, pd.DataFrame([trial_results])], ignore_index=True)
# R2 Score: 0.2936
# MSE Score: 0.6069
# MAE Score: 0.6538
# New best R2 score!
#
# Trial 3/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -2.6000
# MSE Score: 3.0928
# MAE Score: 1.5194
#
# Trial 4/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -1.2334
# MSE Score: 1.9187
# MAE Score: 1.1443
#
# Trial 5/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -6.7299
# MSE Score: 6.6408
# MAE Score: 2.4648
#
# Trial 6/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -5.7419
# MSE Score: 5.7920
# MAE Score: 2.2583
#
# Trial 7/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0507
# MSE Score: 0.8156
# MAE Score: 0.7610
#
# Trial 8/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2400
# MSE Score: 0.6529
# MAE Score: 0.6524
#
# Trial 9/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.0036
# MSE Score: 0.8622
# MAE Score: 0.7962
#
# Trial 10/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -1.7940
# MSE Score: 2.4003
# MAE Score: 1.3802
#
# Trial 11/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -8.5171
# MSE Score: 8.1762
# MAE Score: 2.7485
#
# Trial 12/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -5.3758
# MSE Score: 5.4775
# MAE Score: 2.1998
#
# Trial 13/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2474
# MSE Score: 0.6466
# MAE Score: 0.7061
#
# Trial 14/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1868
# MSE Score: 0.6986
# MAE Score: 0.7245
#
# Trial 15/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.3934
# MSE Score: 1.1971
# MAE Score: 0.8987
#
# Trial 16/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -2.2751
# MSE Score: 2.8136
# MAE Score: 1.4721
#
# Trial 17/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -2.1036
# MSE Score: 2.6663
# MAE Score: 1.4485
#
# Trial 18/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -6.9269
# MSE Score: 6.8100
# MAE Score: 2.4848
#
# Trial 19/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2727
# MSE Score: 0.6248
# MAE Score: 0.6234
#
# Trial 20/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1263
# MSE Score: 0.7506
# MAE Score: 0.7228
#
# Trial 21/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1016
# MSE Score: 0.7718
# MAE Score: 0.7079
#
# Trial 22/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1967
# MSE Score: 0.6901
# MAE Score: 0.6195
#
# Trial 23/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2046
# MSE Score: 0.6834
# MAE Score: 0.6556
#
# Trial 24/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3150
# MSE Score: 0.5885
# MAE Score: 0.6251
# New best R2 score!
#
# Trial 25/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0927
# MSE Score: 0.7795
# MAE Score: 0.6644
#
# Trial 26/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3806
# MSE Score: 0.5321
# MAE Score: 0.6128
# New best R2 score!
#
# Trial 27/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1352
# MSE Score: 0.7430
# MAE Score: 0.6508
#
# Trial 28/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.0044
# MSE Score: 0.8629
# MAE Score: 0.7247
#
# Trial 29/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2674
# MSE Score: 0.6294
# MAE Score: 0.6341
#
# Trial 30/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3821
# MSE Score: 0.5309
# MAE Score: 0.5797
# New best R2 score!
#
# Trial 31/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1979
# MSE Score: 0.6891
# MAE Score: 0.7086
#
# Trial 32/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1513
# MSE Score: 0.7291
# MAE Score: 0.6944
#
# Trial 33/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2954
# MSE Score: 0.6053
# MAE Score: 0.6160
#
# Trial 34/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3311
# MSE Score: 0.5746
# MAE Score: 0.6026
#
# Trial 35/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2481
# MSE Score: 0.6460
# MAE Score: 0.6430
#
# Trial 36/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.0081
# MSE Score: 0.8661
# MAE Score: 0.7564
#
# Trial 37/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3486
# MSE Score: 0.5596
# MAE Score: 0.6632
#
# Trial 38/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.9594
# MSE Score: 1.6833
# MAE Score: 1.0568
#
# Trial 39/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1394
# MSE Score: 0.7393
# MAE Score: 0.7017
#
# Trial 40/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2936
# MSE Score: 0.6069
# MAE Score: 0.5994
#
# Trial 41/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -6.8588
# MSE Score: 6.7515
# MAE Score: 2.4552
#
# Trial 42/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -6.0899
# MSE Score: 6.0909
# MAE Score: 2.3405
#
# Trial 43/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.4157
# MSE Score: 0.5020
# MAE Score: 0.5567
# New best R2 score!
#
# Trial 44/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3987
# MSE Score: 0.5165
# MAE Score: 0.5944
#
# Trial 45/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2996
# MSE Score: 0.6017
# MAE Score: 0.6505
#
# Trial 46/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -1.5230
# MSE Score: 2.1675
# MAE Score: 1.2374
#
# Trial 47/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -8.2569
# MSE Score: 7.9527
# MAE Score: 2.6986
#
# Trial 48/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -5.0622
# MSE Score: 5.2081
# MAE Score: 2.1392
#
# Trial 49/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2675
# MSE Score: 0.6293
# MAE Score: 0.6495
#
# Trial 50/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1417
# MSE Score: 0.7374
# MAE Score: 0.7136
#
# Trial 51/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -1.1767
# MSE Score: 1.8700
# MAE Score: 1.1849
#
# Trial 52/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.2405
# MSE Score: 1.0657
# MAE Score: 0.8815
#
# Trial 53/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -5.4511
# MSE Score: 5.5422
# MAE Score: 2.1914
#
# Trial 54/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -7.9871
# MSE Score: 7.7209
# MAE Score: 2.6154
#
# Trial 55/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0602
# MSE Score: 0.8074
# MAE Score: 0.7132
#
# Trial 56/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0343
# MSE Score: 0.8296
# MAE Score: 0.7830
#
# Trial 57/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2375
# MSE Score: 0.6551
# MAE Score: 0.7079
#
# Trial 58/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.4137
# MSE Score: 0.5037
# MAE Score: 0.5698
#
# Trial 59/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2474
# MSE Score: 0.6465
# MAE Score: 0.6478
#
# Trial 60/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3528
# MSE Score: 0.5560
# MAE Score: 0.6156
#
# Trial 61/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.1058
# MSE Score: 0.9500
# MAE Score: 0.8044
#
# Trial 62/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3487
# MSE Score: 0.5596
# MAE Score: 0.6393
#
# Trial 63/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.1169
# MSE Score: 0.9595
# MAE Score: 0.7795
#
# Trial 64/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3477
# MSE Score: 0.5604
# MAE Score: 0.5983
#
# Trial 65/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.4543
# MSE Score: 0.4689
# MAE Score: 0.5542
# New best R2 score!
#
# Trial 66/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2700
# MSE Score: 0.6271
# MAE Score: 0.6252
#
# Trial 67/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2642
# MSE Score: 0.6322
# MAE Score: 0.6900
#
# Trial 68/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.3600
# MSE Score: 1.1684
# MAE Score: 0.8347
#
# Trial 69/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1012
# MSE Score: 0.7722
# MAE Score: 0.6756
#
# Trial 70/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0723
# MSE Score: 0.7970
# MAE Score: 0.6925
#
# Trial 71/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1389
# MSE Score: 0.7398
# MAE Score: 0.7116
#
# Trial 72/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2529
# MSE Score: 0.6418
# MAE Score: 0.5944
#
# Trial 73/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1519
# MSE Score: 0.7286
# MAE Score: 0.6639
#
# Trial 74/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3176
# MSE Score: 0.5862
# MAE Score: 0.6571
#
# Trial 75/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2977
# MSE Score: 0.6034
# MAE Score: 0.6496
#
# Trial 76/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -4.8409
# MSE Score: 5.0180
# MAE Score: 2.0703
#
# Trial 77/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -4.1015
# MSE Score: 4.3827
# MAE Score: 1.9164
#
# Trial 78/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -4.1046
# MSE Score: 4.3854
# MAE Score: 1.9377
#
# Trial 79/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1552
# MSE Score: 0.7258
# MAE Score: 0.7240
#
# Trial 80/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1578
# MSE Score: 0.7236
# MAE Score: 0.7222
#
# Trial 81/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -2.4083
# MSE Score: 2.9281
# MAE Score: 1.4851
#
# Trial 82/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0735
# MSE Score: 0.7959
# MAE Score: 0.7099
#
# Trial 83/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -5.0980
# MSE Score: 5.2388
# MAE Score: 2.1404
#
# Trial 84/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -5.6917
# MSE Score: 5.7489
# MAE Score: 2.2755
#
# Trial 85/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.5639
# MSE Score: 0.3747
# MAE Score: 0.4986
# New best R2 score!
#
# Trial 86/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.4556
# MSE Score: 0.4677
# MAE Score: 0.5536
#
# Trial 87/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -3.2760
# MSE Score: 3.6735
# MAE Score: 1.7309
#
# Trial 88/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.4159
# MSE Score: 0.5018
# MAE Score: 0.5704
#
# Trial 89/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -5.6478
# MSE Score: 5.7111
# MAE Score: 2.2800
#
# Trial 90/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -7.2886
# MSE Score: 7.1208
# MAE Score: 2.5191
#
# Trial 91/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.2700
# MSE Score: 1.0911
# MAE Score: 0.8035
#
# Trial 92/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2802
# MSE Score: 0.6184
# MAE Score: 0.6352
#
# Trial 93/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0194
# MSE Score: 0.8424
# MAE Score: 0.7136
#
# Trial 94/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2621
# MSE Score: 0.6340
# MAE Score: 0.6845
#
# Trial 95/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1734
# MSE Score: 0.7101
# MAE Score: 0.6802
#
# Trial 96/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2480
# MSE Score: 0.6460
# MAE Score: 0.6711
#
# Trial 97/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3199
# MSE Score: 0.5843
# MAE Score: 0.5946
#
# Trial 98/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3275
# MSE Score: 0.5777
# MAE Score: 0.5857
#
# Trial 99/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2263
# MSE Score: 0.6647
# MAE Score: 0.6856
#
# Trial 100/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0515
# MSE Score: 0.8149
# MAE Score: 0.7510
#
# Trial 101/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2586
# MSE Score: 0.6369
# MAE Score: 0.7090
#
# Trial 102/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3230
# MSE Score: 0.5816
# MAE Score: 0.6449
#
# Trial 103/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.0379
# MSE Score: 0.8917
# MAE Score: 0.7546
#
# Trial 104/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0544
# MSE Score: 0.8124
# MAE Score: 0.7482
#
# Trial 105/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2243
# MSE Score: 0.6664
# MAE Score: 0.7037
#
# Trial 106/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2951
# MSE Score: 0.6056
# MAE Score: 0.6405
#
# Trial 107/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.4694
# MSE Score: 0.4559
# MAE Score: 0.5314
#
# Trial 108/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1678
# MSE Score: 0.7150
# MAE Score: 0.6686
#
# Trial 109/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3389
# MSE Score: 0.5679
# MAE Score: 0.6304
#
# Trial 110/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1681
# MSE Score: 0.7147
# MAE Score: 0.7451
#
# Trial 111/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.1418
# MSE Score: 0.9810
# MAE Score: 0.8216
#
# Trial 112/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.2213
# MSE Score: 1.0492
# MAE Score: 0.8270
#
# Trial 113/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -6.2533
# MSE Score: 6.2313
# MAE Score: 2.3551
#
# Trial 114/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -5.1070
# MSE Score: 5.2465
# MAE Score: 2.1510
#
# Trial 115/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3729
# MSE Score: 0.5387
# MAE Score: 0.5920
#
# Trial 116/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3443
# MSE Score: 0.5633
# MAE Score: 0.6046
#
# Trial 117/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -2.2785
# MSE Score: 2.8166
# MAE Score: 1.4697
#
# Trial 118/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1934
# MSE Score: 0.6930
# MAE Score: 0.6643
#
# Trial 119/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -4.0952
# MSE Score: 4.3773
# MAE Score: 1.8502
#
# Trial 120/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -6.7592
# MSE Score: 6.6660
# MAE Score: 2.4482
#
# Trial 121/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2499
# MSE Score: 0.6444
# MAE Score: 0.6390
#
# Trial 122/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2223
# MSE Score: 0.6682
# MAE Score: 0.7121
#
# Trial 123/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -2.4278
# MSE Score: 2.9448
# MAE Score: 1.5122
#
# Trial 124/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -1.1758
# MSE Score: 1.8692
# MAE Score: 1.1501
#
# Trial 125/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -7.4458
# MSE Score: 7.2558
# MAE Score: 2.5536
#
# Trial 126/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -5.2097
# MSE Score: 5.3348
# MAE Score: 2.1602
#
# Trial 127/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1937
# MSE Score: 0.6927
# MAE Score: 0.6348
#
# Trial 128/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.1397
# MSE Score: 0.9792
# MAE Score: 0.8079
#
# Trial 129/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1909
# MSE Score: 0.6951
# MAE Score: 0.7189
#
# Trial 130/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.0319
# MSE Score: 0.8865
# MAE Score: 0.7969
#
# Trial 131/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1479
# MSE Score: 0.7320
# MAE Score: 0.6653
#
# Trial 132/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3387
# MSE Score: 0.5681
# MAE Score: 0.6333
#
# Trial 133/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2590
# MSE Score: 0.6366
# MAE Score: 0.6686
#
# Trial 134/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0971
# MSE Score: 0.7757
# MAE Score: 0.7350
#
# Trial 135/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0529
# MSE Score: 0.8137
# MAE Score: 0.7540
#
# Trial 136/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1409
# MSE Score: 0.7380
# MAE Score: 0.6606
#
# Trial 137/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2608
# MSE Score: 0.6351
# MAE Score: 0.6939
#
# Trial 138/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2694
# MSE Score: 0.6276
# MAE Score: 0.6495
#
# Trial 139/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2327
# MSE Score: 0.6592
# MAE Score: 0.6303
#
# Trial 140/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.1592
# MSE Score: 0.9959
# MAE Score: 0.8143
#
# Trial 141/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2818
# MSE Score: 0.6170
# MAE Score: 0.6164
#
# Trial 142/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.0581
# MSE Score: 0.9090
# MAE Score: 0.7600
#
# Trial 143/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'leaky_relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0391
# MSE Score: 0.8255
# MAE Score: 0.7359
#
# Trial 144/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'leaky_relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1564
# MSE Score: 0.7247
# MAE Score: 0.7093
#
# Trial 145/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.1561
# MSE Score: 0.9932
# MAE Score: 0.8631
#
# Trial 146/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0037
# MSE Score: 0.8560
# MAE Score: 0.7722
#
# Trial 147/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.1760
# MSE Score: 1.0103
# MAE Score: 0.8163
#
# Trial 148/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2311
# MSE Score: 0.6606
# MAE Score: 0.7040
#
# Trial 149/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -3.8384
# MSE Score: 4.1567
# MAE Score: 1.9203
#
# Trial 150/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -4.2069
# MSE Score: 4.4733
# MAE Score: 2.0052
#
# Trial 151/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1073
# MSE Score: 0.7669
# MAE Score: 0.7523
#
# Trial 152/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0907
# MSE Score: 0.7812
# MAE Score: 0.7770
#
# Trial 153/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.8805
# MSE Score: 1.6156
# MAE Score: 1.0688
#
# Trial 154/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -2.2104
# MSE Score: 2.7581
# MAE Score: 1.5021
#
# Trial 155/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -5.2686
# MSE Score: 5.3854
# MAE Score: 2.2134
#
# Trial 156/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -3.5783
# MSE Score: 3.9332
# MAE Score: 1.8720
#
# Trial 157/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.1195
# MSE Score: 0.9618
# MAE Score: 0.8229
#
# Trial 158/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1972
# MSE Score: 0.6897
# MAE Score: 0.7053
#
# Trial 159/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -1.4445
# MSE Score: 2.1001
# MAE Score: 1.2420
#
# Trial 160/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -3.2705
# MSE Score: 3.6688
# MAE Score: 1.7884
#
# Trial 161/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -4.8916
# MSE Score: 5.0615
# MAE Score: 2.1572
#
# Trial 162/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -5.2610
# MSE Score: 5.3789
# MAE Score: 2.1965
#
# Trial 163/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.1246
# MSE Score: 0.9661
# MAE Score: 0.8138
#
# Trial 164/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3365
# MSE Score: 0.5700
# MAE Score: 0.6333
#
# Trial 165/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.0465
# MSE Score: 0.8991
# MAE Score: 0.8182
#
# Trial 166/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1072
# MSE Score: 0.7670
# MAE Score: 0.7573
#
# Trial 167/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1364
# MSE Score: 0.7419
# MAE Score: 0.7168
#
# Trial 168/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.1333
# MSE Score: 0.9736
# MAE Score: 0.8399
#
# Trial 169/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0182
# MSE Score: 0.8435
# MAE Score: 0.7740
#
# Trial 170/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.0191
# MSE Score: 0.8755
# MAE Score: 0.8223
#
# Trial 171/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.4909
# MSE Score: 1.2808
# MAE Score: 0.9450
#
# Trial 172/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0785
# MSE Score: 0.7917
# MAE Score: 0.7534
#
# Trial 173/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2766
# MSE Score: 0.6215
# MAE Score: 0.6909
#
# Trial 174/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.2124
# MSE Score: 1.0416
# MAE Score: 0.8741
#
# Trial 175/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1968
# MSE Score: 0.6900
# MAE Score: 0.7416
#
# Trial 176/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: -0.0176
# MSE Score: 0.8742
# MAE Score: 0.7921
#
# Trial 177/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3580
# MSE Score: 0.5516
# MAE Score: 0.6501
#
# Trial 178/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0581
# MSE Score: 0.8092
# MAE Score: 0.7715
#
# Trial 179/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.2080
# MSE Score: 0.6804
# MAE Score: 0.6805
#
# Trial 180/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.3982
# MSE Score: 0.5170
# MAE Score: 0.6258
#
# Trial 181/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0252
# MSE Score: 0.8375
# MAE Score: 0.7711
#
# Trial 182/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.0704
# MSE Score: 0.7986
# MAE Score: 0.7315
#
# Trial 183/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'tanh', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# R2 Score: 0.1755
# MSE Score: 0.7084
# MAE Score: 0.6978
#
# Trial 184/7776
# Current parameters: {'num_epochs': 250, 'num_units': [48, 24, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'tanh', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 16]}
# ...
# R2 Score: 0.3121
# MSE Score: 0.5909
# MAE Score: 0.6137
#
# Trial 1167/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.4304
# MSE Score: 0.4893
# MAE Score: 0.5463
#
# Trial 1168/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.2822
# MSE Score: 0.6166
# MAE Score: 0.6354
#
# Trial 1169/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: -6.2480
# MSE Score: 6.2268
# MAE Score: 2.3227
#
# Trial 1170/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adam', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: -6.2411
# MSE Score: 6.2208
# MAE Score: 2.3428
#
# Trial 1171/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.3301
# MSE Score: 0.5755
# MAE Score: 0.6213
#
# Trial 1172/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.1801
# MSE Score: 0.7044
# MAE Score: 0.6853
#
# Trial 1173/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.1601
# MSE Score: 0.7216
# MAE Score: 0.7160
#
# Trial 1174/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.3814
# MSE Score: 0.5315
# MAE Score: 0.5982
#
# Trial 1175/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.2732
# MSE Score: 0.6244
# MAE Score: 0.7075
#
# Trial 1176/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.4054
# MSE Score: 0.5108
# MAE Score: 0.5826
#
# Trial 1177/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.0351
# MSE Score: 0.8289
# MAE Score: 0.7336
#
# Trial 1178/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.3884
# MSE Score: 0.5254
# MAE Score: 0.6048
#
# Trial 1179/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.1242
# MSE Score: 0.7524
# MAE Score: 0.7182
#
# Trial 1180/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.1452
# MSE Score: 0.7344
# MAE Score: 0.6922
#
# Trial 1181/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.4734
# MSE Score: 0.4524
# MAE Score: 0.5913
#
# Trial 1182/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.3251
# MSE Score: 0.5798
# MAE Score: 0.6374
#
# Trial 1183/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.2375
# MSE Score: 0.6551
# MAE Score: 0.6900
#
# Trial 1184/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.1421
# MSE Score: 0.7370
# MAE Score: 0.6864
#
# Trial 1185/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.2753
# MSE Score: 0.6226
# MAE Score: 0.6649
#
# Trial 1186/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.3440
# MSE Score: 0.5635
# MAE Score: 0.6022
#
# Trial 1187/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.1890
# MSE Score: 0.6967
# MAE Score: 0.7142
#
# Trial 1188/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'sgd', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.1958
# MSE Score: 0.6909
# MAE Score: 0.7081
#
# Trial 1189/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.2601
# MSE Score: 0.6356
# MAE Score: 0.6501
#
# Trial 1190/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.0567
# MSE Score: 0.8104
# MAE Score: 0.7447
#
# Trial 1191/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: -1.0490
# MSE Score: 1.7603
# MAE Score: 1.0712
#
# Trial 1192/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.2364
# MSE Score: 0.6560
# MAE Score: 0.6256
#
# Trial 1193/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: -6.8728
# MSE Score: 6.7635
# MAE Score: 2.4846
#
# Trial 1194/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: -6.6005
# MSE Score: 6.5296
# MAE Score: 2.3955
#
# Trial 1195/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.3480
# MSE Score: 0.5602
# MAE Score: 0.6484
#
# Trial 1196/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.3184
# MSE Score: 0.5856
# MAE Score: 0.6191
#
# Trial 1197/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: -1.9195
# MSE Score: 2.5082
# MAE Score: 1.4032
#
# Trial 1198/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: -1.5347
# MSE Score: 2.1775
# MAE Score: 1.3245
#
# Trial 1199/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: -8.6423
# MSE Score: 8.2837
# MAE Score: 2.7595
#
# Trial 1200/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: -6.1256
# MSE Score: 6.1217
# MAE Score: 2.2965
#
# Trial 1201/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.0867
# MSE Score: 0.7847
# MAE Score: 0.7443
#
# Trial 1202/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.3, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.4329
# MSE Score: 0.4872
# MAE Score: 0.5854
#
# Trial 1203/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: -0.4256
# MSE Score: 1.2247
# MAE Score: 0.9050
#
# Trial 1204/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.3, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: -4.0651
# MSE Score: 4.3514
# MAE Score: 1.9407
#
# Trial 1205/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: -6.7223
# MSE Score: 6.6343
# MAE Score: 2.4193
#
# Trial 1206/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.3, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'adamw', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: -4.2918
# MSE Score: 4.5462
# MAE Score: 1.9449
#
# Trial 1207/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.2610
# MSE Score: 0.6349
# MAE Score: 0.6349
#
# Trial 1208/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.1, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.4213
# MSE Score: 0.4972
# MAE Score: 0.5816
#
# Trial 1209/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.2754
# MSE Score: 0.6225
# MAE Score: 0.6255
#
# Trial 1210/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.1, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.3035
# MSE Score: 0.5984
# MAE Score: 0.6733
#
# Trial 1211/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.3256
# MSE Score: 0.5794
# MAE Score: 0.6371
#
# Trial 1212/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.1, 'lr': 0.0001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.0737
# MSE Score: 0.7958
# MAE Score: 0.7791
#
# Trial 1213/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: -0.0154
# MSE Score: 0.8723
# MAE Score: 0.7874
#
# Trial 1214/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.2, 'lr': 0.001, 'decay': 1e-05, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: -0.0705
# MSE Score: 0.9197
# MAE Score: 0.7553
#
# Trial 1215/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 0.0001, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: 0.2675
# MSE Score: 0.6293
# MAE Score: 0.6746
#
# Trial 1216/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.2, 'lr': 0.0005, 'decay': 1e-05, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 8]}
# R2 Score: -0.1876
# MSE Score: 1.0203
# MAE Score: 0.8135
#
# Trial 1217/7776
# Current parameters: {'num_epochs': 250, 'num_units': [32, 16, 16, 8], 'drop': 0.2, 'lr': 0.0001, 'decay': 0.0001, 'acts': 'relu', 'opts': 'rmsprop', 'patience': 20, 'blocks': [32, 16, 8]}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 best_params, best_model, best_metrics = grid_search_CNN(target_r2=0.9,data_folder="data")
#
# Cell In[13], line 101, in grid_search_CNN(target_r2, data_folder)
#      89 model, criterion, optimizer = createCNNmodel(
#      90     hidden_units=units,
#      91     blocks=blocks,
#    (...)
#      97     input_length=input_dim
#      98 )
#     100 # Train model and get metrics
# --> 101 trained_model = trainAndEval(
#     102     model, criterion, optimizer,
#     103     max_epochs=epochs,
#     104     patience=param_grid["PATIENCE"],
#     105     train_loader=train_loader,
#     106     val_loader=val_loader
#     107 )
#     109 # Get predictions on test set
#     110 model.eval()
#
# Cell In[12], line 19, in trainAndEval(model, criterion, optimizer, train_loader, val_loader, max_epochs, patience)
#      17 outputs = model(batch_X)
#      18 loss = criterion(outputs, batch_y)
# ---> 19 loss.backward()
#      20 optimizer.step()
#      22 running_train_loss += loss.item() * batch_X.size(0)
#
# File c:\Users\LEGION\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File c:\Users\LEGION\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File c:\Users\LEGION\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
PATH = "CNN_models/best_model_filtered_00001.pth"
model = createCNNmodel([32,16,16], [32,16,16,8], 0.3, 0.01, 1e-4, "relu", "adam")
model.load_state_dict(torch.load(PATH, weights_only=True))

all_preds = []
all_targets = []

test_loader = get_SNP("filtered_001.csv")
with torch.no_grad():
    for batch_X, batch_y in test_loader:
        batch_X = batch_X.to(device)
        outputs = model(batch_X)
        all_preds.append(outputs.cpu().numpy())
        all_targets.append(batch_y.numpy().reshape(-1, 1))  # Reshape to match predictions

y_pred = np.concatenate(all_preds).reshape(-1)
y_true = np.concatenate(all_targets).reshape(-1)

# Calculate metrics
mse = mean_squared_error(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)
r2 = r2_score(y_true, y_pred)

print("\n=== Final Evaluation on Test Set ===")
print(f"MSE:  {mse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R^2:  {r2:.4f}")

# Visualize results
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.title("Learning Curve (1D CNN)")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.scatter(y_true, y_pred, alpha=0.5)
min_val = min(min(y_true), min(y_pred))
max_val = max(max(y_true), max(y_pred))
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.title("Predicted vs True Phenotype")
plt.xlabel("True Phenotype")
plt.ylabel("Predicted Phenotype")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 PATH = "CNN_models/best_model_filtered_00001.pth"
# ----> 2 model = createCNNmodel([32,16,16], [32,16,16,8], 0.3, 0.01, 1e-4, "relu", "adam")
#       3 model.load_state_dict(torch.load(PATH, weights_only=True))
#       5 all_preds = []
#
# Cell In[11], line 98, in createCNNmodel(blocks, hidden_units, drop, lr, decay, input_length, activation_type, optimizer_type)
#      94         x = self.ffn_layers['output'](x)
#      95         return x
# ---> 98 model = CNNRegressor(blocks,hidden_units, drop, activation_type, input_length)
#     100 criterion = nn.MSELoss()
#     101 optimizers = {
#     102 'adam': lambda: torch.optim.Adam(model.parameters(), lr=lr, weight_decay=decay),
#     103 'sgd': lambda: torch.optim.SGD(model.parameters(), lr=lr, weight_decay=decay, momentum=0.9),
#     104 "adamw": lambda: torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=decay),
#     105 "rmsprop": lambda: torch.optim.RMSprop(model.parameters(), lr=lr, weight_decay=decay, momentum=0.9),
#     106 }
#
# Cell In[11], line 42, in createCNNmodel.<locals>.CNNRegressor.__init__(self, blocks, hidden_units, drop, activation_type, input_length)
#      40 # Account for each pooling layer
#      41 for _ in range(self.nCons):
# ---> 42     output_length = output_length // 2
#      44 flattened_size = blocks[-1] * output_length
#      47 #Dense part
#
# TypeError: unsupported operand type(s) for //: 'str' and 'int'

# %%
def importance_graph(model, snp_number=20):
    N = snp_number
    
    input_weights = model.state_dict()[list(model.state_dict().keys())[0]]
    
    snp_weights = input_weights.mean(dim=0).cpu().numpy()
    
    fig_height = max(5, N * 0.4)
    plt.figure(figsize=(12, fig_height))

    snp_names = np.array(X.columns)
    sorted_indices = np.argsort(snp_weights)

    plt.barh(snp_names[sorted_indices][-N:], snp_weights[sorted_indices][-N:], color="forestgreen", label="Positive Effect")
    plt.barh(snp_names[sorted_indices][:N], snp_weights[sorted_indices][:N], color="firebrick", label="Negative Effect")

    plt.xlabel("Feature Importance (Weight Value)")
    plt.ylabel("SNPs")
    plt.title("Top SNPs Affecting Phenotype")
    plt.gca().invert_yaxis()
    plt.legend()
    plt.savefig(f"important_{snp_number}_snps.png", dpi=300)

importance_graph(best_model, 20)
